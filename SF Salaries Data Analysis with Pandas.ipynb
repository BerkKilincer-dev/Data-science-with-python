# %%
import pandas as pd

# %%
Sf =pd.read_csv('Salaries.csv')
# Out:
# C:\Users\berkk\AppData\Local\Temp\ipykernel_28440\3966264654.py:1: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   Sf =pd.read_csv('Salaries.csv')

# %%
Sf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
Sf.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
Sf.shape
# Out:
# (148654, 13)

# %%
Sf.isna()
# Out:
#            Id  EmployeeName  JobTitle  BasePay  OvertimePay  OtherPay  \
# 0       False         False     False    False        False     False
# 1       False         False     False    False        False     False
# 2       False         False     False    False        False     False
# 3       False         False     False    False        False     False
# 4       False         False     False    False        False     False
# ...       ...           ...       ...      ...          ...       ...
# 148649  False         False     False    False        False     False
# 148650  False         False     False    False        False     False
# 148651  False         False     False    False        False     False
# 148652  False         False     False    False        False     False
# 148653  False         False     False    False        False     False
#
#         Benefits  TotalPay  TotalPayBenefits   Year  Notes  Agency  Status
# ...

# %%
Sf.isna().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %%
for col in Sf.columns:
     print(col)
# Out:
# Id
# EmployeeName
# JobTitle
# BasePay
# OvertimePay
# OtherPay
# Benefits
# TotalPay
# TotalPayBenefits
# Year
# Notes
# Agency
# Status

# %%
t={}
for col in Sf.columns:
  t[col] =Sf[col].value_counts()#value_counts her farklı değerden kaç tane var

# %%
t['BasePay']
# Out:
# BasePay
# 0.0         875
# 0.00        423
# 54703.00    327
# 55026.0     297
# 48472.4     210
#            ...
# 68032.05      1
# 71342.57      1
# 75459.88      1
# 55768.91      1
# 474.52        1
# Name: count, Length: 109900, dtype: int64

# %%
Sf['BasePay']
# Out:
# 0            167411.18
# 1            155966.02
# 2            212739.13
# 3              77916.0
# 4             134401.6
#               ...
# 148649            0.00
# 148650    Not Provided
# 148651    Not Provided
# 148652    Not Provided
# 148653            0.00
# Name: BasePay, Length: 148654, dtype: object

# %%
Sf['BasePay'].head()
# Out:
# 0    167411.18
# 1    155966.02
# 2    212739.13
# 3      77916.0
# 4     134401.6
# Name: BasePay, dtype: object

# %%
Sf['BasePay'].tail()
# Out:
# 148649            0.00
# 148650    Not Provided
# 148651    Not Provided
# 148652    Not Provided
# 148653            0.00
# Name: BasePay, dtype: object

# %%
Sf['BasePay'].head(60)
Sf['BasePay'].tail(60)
# Out:
# 148594            0.00
# 148595           40.28
# 148596            0.00
# 148597            0.00
# 148598           37.25
# 148599           37.25
# 148600           37.23
# 148601           34.88
# 148602           34.75
# 148603            0.00
# 148604           34.03
# 148605            0.00
# 148606           31.75
# 148607           31.43
# 148608           21.76
# 148609           26.94
# 148610           21.22
# 148611            0.00
# 148612            0.00
# 148613           19.97
# 148614            0.00
# 148615            0.00
# 148616           21.48
# 148617           17.26
# 148618            0.00
# 148619            6.04
# 148620           15.50
# 148621            0.00
# 148622            0.00
# 148623            0.00
# 148624            0.00
# 148625            0.00
# 148626            0.00
# 148627            0.00
# 148628            0.00
# 148629            0.00
# 148630            0.00
# 148631            0.00
# 148632            0.00
# 148633            0.00
# ...

# %%
Sf.iloc[100]
# Out:
# Id                                                 101
# EmployeeName                              KEVIN TAYLOR
# JobTitle            BATTALION CHIEF, (FIRE DEPARTMENT)
# BasePay                                      168692.65
# OvertimePay                                   33656.87
# OtherPay                                      21502.83
# Benefits                                           NaN
# TotalPay                                     223852.35
# TotalPayBenefits                             223852.35
# Year                                              2011
# Notes                                              NaN
# Agency                                   San Francisco
# Status                                             NaN
# Name: 100, dtype: object

# %%
Sf.iloc[100:150]
# Out:
#       Id        EmployeeName  \
# 100  101        KEVIN TAYLOR
# 101  102           ERIKA HOO
# 102  103     LAUIFI SEUMAALA
# 103  104       EDWARD DENNIS
# 104  105       PATRIC STEELE
# 105  106       MICHAEL WALSH
# 106  107          SAMSON LAI
# 107  108         ANA SAMPERA
# 108  109  GLORIA GARCIA ORME
# 109  110      SCOTT SCHOLZEN
# 110  111          MARK SMITH
# 111  112       C PETRUZZELLA
# 112  113       JOHN HALEY JR
# 113  114     NELA PONFERRADA
# 114  115       CHARLES SCOTT
# 115  116       LISETTE ADAMS
# 116  117        JACKSON WONG
# 117  118          IRENE SUNG
# 118  119         KHAIRUL ALI
# 119  120       LESLIE DUBBIN
# 120  121  MICHAEL CASTAGNOLA
# 121  122    SHELLEY MITCHELL
# 122  123        SEAN BONETTI
# 123  124       SUSAN ILNICKI
# 124  125      TYRONNE JULIAN
# 125  126     SHARON FERRIGNO
# 126  127    SHANNON SAKOWSKI
# 127  128         JOHN HICKEY
# 128  129       GLEN KOJIMOTO
# 129  130          EDWARD CHU
# 130  131       SOFIA MATHEWS
# ...

# %%
Sf.iloc[100:150]['BasePay']
Sf['BasePay'].iloc[100:150]
# Out:
# 100    168692.65
# 101     123105.0
# 102    105934.69
# 103      88400.7
# 104    105934.64
# 105    110474.93
# 106    149362.86
# 107     188708.0
# 108     188708.0
# 109    105934.67
# 110    206057.69
# 111     63811.18
# 112    220115.22
# 113     188708.0
# 114      88400.7
# 115    121628.34
# 116    219804.34
# 117    191054.19
# 118    150432.85
# 119     179648.0
# 120    140546.88
# 121    203658.55
# 122     122594.0
# 123    188889.44
# 124      88062.0
# 125    185369.68
# 126    192170.93
# 127    168692.63
# 128    140546.85
# 129     123105.0
# 130    158603.68
# 131    141648.87
# 132    215799.48
# 133    149044.93
# 134    166203.84
# 135    123416.25
# 136    182368.79
# 137    215180.75
# 138    213907.72
# 139    213907.72
# 140    213907.72
# 141     123105.0
# 142    130481.53
# 143    105934.63
# 144    206438.88
# 145    140546.63
# 146     183040.0
# 147    105934.69
# 148    167070.08
# 149     183040.0
# Name: BasePay, dtype: object

# %%
t2={}
for col in Sf.columns:
    t2[col] = Sf[col].nunique()

# %%
t2['BasePay']#kaç farklı maaş var
# Out:
# 109900

# %%
for column in Sf.columns:
    print(pd.api.types.infer_dtype(Sf[column]))#gerçek veri tipini tahmin eder
# Out:
# integer
# string
# string
# mixed
# mixed
# mixed
# mixed
# floating
# floating
# integer
# floating
# string
# string

# %%
Sf['BasePay'].apply(type).value_counts()# her hücrenin tipini alır  kaç float kaç str var
# Out:
# BasePay
# <class 'float'>    131072
# <class 'str'>       17582
# Name: count, dtype: int64

# %%
Sf['BasePay'].apply(type).nunique()#kç farklı veri tipi var
# Out:
# 2

# %%
Sf[Sf['BasePay'].apply(type) == str]#maaşı string olan tüm satırlar
# Out:
#             Id         EmployeeName                      JobTitle  \
# 131072  131073     Barbara A George              Transit Operator
# 131073  131074  Daniel J Koledin Ii   Electronic Maintenance Tech
# 131074  131075      Kathleen Devine  Employment & Training Spec 3
# 131075  131076  Carmen I Rutherford     Licensed Vocational Nurse
# 131076  131077      Milton T Hodges                     Custodian
# ...        ...                  ...                           ...
# 148649  148650        Roy I Tillery                     Custodian
# 148650  148651         Not provided                  Not provided
# 148651  148652         Not provided                  Not provided
# 148652  148653         Not provided                  Not provided
# 148653  148654            Joe Lopez    Counselor, Log Cabin Ranch
#
#              BasePay   OvertimePay      OtherPay      Benefits  TotalPay  \
# 131072      60618.25       1852.91        971.04      31668.21  63442.20
# ...

# %%
Sf[Sf['BasePay'].apply(type) == str]['BasePay']#dataframde basepay stununun veri tipi string olan satalarin icinden sadece basepay görülmesi
# Out:
# 131072        60618.25
# 131073        68712.00
# 131074        68448.94
# 131075        64084.00
# 131076        53982.99
#               ...
# 148649            0.00
# 148650    Not Provided
# 148651    Not Provided
# 148652    Not Provided
# 148653            0.00
# Name: BasePay, Length: 17582, dtype: object

# %%
#dataframe de BasePay sutunun veri tipi string olan dataların içinden BasePay verilerinden 
#her birinden kaçar adet var 
Sf[Sf['BasePay'].apply(type) == str]['BasePay'].value_counts()
# Out:
# BasePay
# 0.00        423
# 54703.00    327
# 65055.00     48
# 54703.01     44
# 18594.00     43
#            ...
# 38812.01      1
# 44245.16      1
# 42966.87      1
# 32971.59      1
# 17914.72      1
# Name: count, Length: 14809, dtype: int64

# %%
#uzunluk 
len(Sf[Sf['BasePay'].apply(type) ==str]['BasePay'].value_counts())
# Out:
# 14809

# %%
#BasePay sutunun veri tipi string olan dataların icinden sadece BasePay verilerinini her biri
string_values =Sf[Sf['BasePay'].apply(type)==str]['BasePay'].unique()
string_values
# Out:
# array(['60618.25', '68712.00', '68448.94', ..., '6.04', '15.50',
#        'Not Provided'], dtype=object)

# %%
#string_values icinde '.' yer almayan stringler
for i in string_values:
    if '.' not in i:
        print(i)
# Out:
# Not Provided

# %%
#OvertimePay
#Benefits
#icinde kontrol et
string_values2 =Sf[Sf['Benefits'].apply(type) ==str]['Benefits'].unique()
for i in string_values2:
    if '.' not in i:
        print(i)
# Out:
# Not Provided

# %%
#BasePay column minimum datayi al
# 'BasePay' sütununda sayısal olmayan değerleri NaN'a dönüştür ve sütunu float tipine çevir
Sf['BasePay'] =pd.to_numeric(Sf['BasePay'],errors='coerce')
#minmum değeri al
Sf['BasePay'].min()
# Out:
# -166.01

# %%
#df['ABC'].map(type) != str
#BasePay  column'unda veri tipi var mi yok mu kontrol et
Sf['BasePay'].map(type) == str
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 148649    False
# 148650    False
# 148651    False
# 148652    False
# 148653    False
# Name: BasePay, Length: 148654, dtype: bool

# %%
#bir column'da tek data tipi olur. burada karisik

# %%
#dataframe'de BasePay sutunun veri tipi string olan datalarin butun dataset icinde gorulmesi
#map(type)==str
Sf[Sf['BasePay'].map(type)== str]
# Out:
# Empty DataFrame
# Columns: [Id, EmployeeName, JobTitle, BasePay, OvertimePay, OtherPay, Benefits, TotalPay, TotalPayBenefits, Year, Notes, Agency, Status]
# Index: []

# %%
#dataframe'de BasePay sutunun veri tipi string olan datalarin icinden sadece BasePay gorulmesi
#map(type)==str
Sf[Sf['BasePay'].map(type) == str]['BasePay']
# Out:
# Series([], Name: BasePay, dtype: float64)

# %%
#butun columnlari gor
Sf.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
#warnings kutuphanesini import et
import warnings
warnings.filterwarnings('ignore')

# %%
#icinde Not Provided ve Not provided gecen columnlari gor
not_provided_col=[x for x in Sf.columns if 'Not Provided' in Sf[x].values or 'Not provided' in Sf[x].values]
not_provided_col
# Out:
# ['EmployeeName', 'JobTitle', 'OvertimePay', 'OtherPay', 'Benefits']

# %%
Sf
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
Sf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(4), int64(2), object(7)
# memory usage: 14.7+ MB

# %%
Sf.isna().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                609
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %%
#Salaries.csv'den dataframe yap
#na_values
#Not Provided, Not provided
SF=pd.read_csv('Salaries.csv',
              na_values=['Not Provided','Not provided'])
SF.isna().sum()
# Out:
# Id                       0
# EmployeeName             6
# JobTitle                 4
# BasePay                609
# OvertimePay              4
# OtherPay                 4
# Benefits             36163
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %%
#dataframe info
SF['BasePay'].max()
# Out:
# 319275.01

# %%
#Benefits, Notes, Agency, Status columnlarini sil

SF=SF.drop(columns=['Benefits', 'Notes', 'Agency', 'Status'])
SF
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651                NaN
# 148651  148652                NaN
# 148652  148653                NaN
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
#dataframe info al
SF.isna().sum()
# Out:
# Id                    0
# EmployeeName          6
# JobTitle              4
# BasePay             609
# OvertimePay           4
# OtherPay              4
# TotalPay              0
# TotalPayBenefits      0
# Year                  0
# dtype: int64

# %%
#dataframe eksik data toplamina bak
#isna
#sum
SF=SF.dropna()
SF.isna().sum()
# Out:
# Id                  0
# EmployeeName        0
# JobTitle            0
# BasePay             0
# OvertimePay         0
# OtherPay            0
# TotalPay            0
# TotalPayBenefits    0
# Year                0
# dtype: int64

# %%
#eksik columnlari sildikten sonra
#dataframe eksik data toplamina bak
SF.isna().sum()
# Out:
# Id                  0
# EmployeeName        0
# JobTitle            0
# BasePay             0
# OvertimePay         0
# OtherPay            0
# TotalPay            0
# TotalPayBenefits    0
# Year                0
# dtype: int64

# %%
#dataframe info
SF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 148043 entries, 0 to 148653
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148043 non-null  int64
#  1   EmployeeName      148043 non-null  object
#  2   JobTitle          148043 non-null  object
#  3   BasePay           148043 non-null  float64
#  4   OvertimePay       148043 non-null  float64
#  5   OtherPay          148043 non-null  float64
#  6   TotalPay          148043 non-null  float64
#  7   TotalPayBenefits  148043 non-null  float64
#  8   Year              148043 non-null  int64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 11.3+ MB

# %%
#describe
SF.describe()
# Out:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  148043.000000  148043.000000  148043.000000  148043.000000
# mean    74193.290902   66325.398119    5086.501378    3645.655768
# std     42948.417213   42764.898947   11473.068388    8019.552578
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     37012.500000   33587.350000       0.000000       0.000000
# 50%     74024.000000   65007.450000       0.000000     817.100000
# 75%    111639.500000   94691.050000    4695.180000    4242.855000
# max    148654.000000  319275.010000  245131.880000  400184.250000
#
#             TotalPay  TotalPayBenefits           Year
# count  148043.000000     148043.000000  148043.000000
# mean    75057.555265      94037.888854    2012.520666
# std     50410.007571      62683.725358       1.119390
# min      -618.130000       -618.130000    2011.000000
# 25%     36956.850000      45074.275000    2012.000000
# ...

# %%
#EmployeeName column bak
SF['EmployeeName']
# Out:
# 0            NATHANIEL FORD
# 1              GARY JIMENEZ
# 2            ALBERT PARDINI
# 3         CHRISTOPHER CHONG
# 4           PATRICK GARDNER
#                 ...
# 148645     Carolyn A Wilson
# 148647       Joann Anderson
# 148648          Leon Walker
# 148649        Roy I Tillery
# 148653            Joe Lopez
# Name: EmployeeName, Length: 148043, dtype: object

# %%
#ilk veriyi al
#0
SF['EmployeeName'][0]
# Out:
# 'NATHANIEL FORD'

# %%
#EmployeeName column da herkesin adi NATHANIEL FORD mu degil mi kontrol et
#True, False
SF['EmployeeName']=='NATHANIEL FORD'
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 148645    False
# 148647    False
# 148648    False
# 148649    False
# 148653    False
# Name: EmployeeName, Length: 148043, dtype: bool

# %%
#EmployeeName columnda adi NATHANIEL FORD olan kisinin sutununu getir
SF[SF['EmployeeName']=='NATHANIEL FORD']
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay   TotalPay  TotalPayBenefits  Year
# 0  167411.18          0.0  400184.25  567595.43         567595.43  2011

# %%
#EmployeeName columnda adi NATHANIEL FORD olan kisinin TotalPayBenefits bilgisi
SF[SF['EmployeeName']=='NATHANIEL FORD']['TotalPayBenefits']
# Out:
# 0    567595.43
# Name: TotalPayBenefits, dtype: float64

# %%
SF[SF['EmployeeName']=='NATHANIEL FORD']['TotalPayBenefits'].values[0]
# Out:
# 567595.43

# %%
#BasePay  column'unda kac farkli data tipi var
#BasePay  column'unda her farkli data tipinden kacar adet var
#apply(type)
#value_counts()
#nunique
SF['BasePay'].apply(type).value_counts()
# Out:
# BasePay
# <class 'float'>    148043
# Name: count, dtype: int64

# %%
#dataframe info
SF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 148043 entries, 0 to 148653
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148043 non-null  int64
#  1   EmployeeName      148043 non-null  object
#  2   JobTitle          148043 non-null  object
#  3   BasePay           148043 non-null  float64
#  4   OvertimePay       148043 non-null  float64
#  5   OtherPay          148043 non-null  float64
#  6   TotalPay          148043 non-null  float64
#  7   TotalPayBenefits  148043 non-null  float64
#  8   Year              148043 non-null  int64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 15.3+ MB

# %%
#BasePay column min deger
SF['BasePay'].min()
# Out:
# -166.01

# %%
#BasePay column max deger
SF['BasePay'].max()
# Out:
# 319275.01

# %%
#BasePay column max degere sahip olan kisinin satiri
SF[SF['BasePay']==SF['BasePay'].max()]
# Out:
#           Id    EmployeeName         JobTitle    BasePay  OvertimePay  \
# 72925  72926  Gregory P Suhr  Chief of Police  319275.01          0.0
#
#        OtherPay   TotalPay  TotalPayBenefits  Year
# 72925  20007.06  339282.07         425815.28  2013

# %%
#BasePay column max degere sahip olan kisinin adi
SF[SF['BasePay']==SF['BasePay'].max()]['EmployeeName']
# Out:
# 72925    Gregory P Suhr
# Name: EmployeeName, dtype: object

# %%
SF[SF['BasePay']==SF['BasePay'].max()]['EmployeeName'].values[0]
# Out:
# 'Gregory P Suhr'

# %%
#JobTitle column
SF[SF['BasePay']==SF['BasePay'].max()]['JobTitle'].values[0]
# Out:
# 'Chief of Police'

# %%
#mesleginin adinda POLICE olanlar
SF['JobTitle']
# Out:
# 0         GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                        CAPTAIN III (POLICE DEPARTMENT)
# 2                        CAPTAIN III (POLICE DEPARTMENT)
# 3                   WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4           DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#                                ...
# 148645                         Human Services Technician
# 148647                       Communications Dispatcher 2
# 148648                                         Custodian
# 148649                                         Custodian
# 148653                        Counselor, Log Cabin Ranch
# Name: JobTitle, Length: 148043, dtype: object

# %%
POLICE=SF.loc[SF['JobTitle'].str.contains('POLICE')]
len(POLICE)
# Out:
# 2512

# %%
POLICE
# Out:
#           Id             EmployeeName  \
# 1          2             GARY JIMENEZ
# 2          3           ALBERT PARDINI
# 11        12         PATRICIA JACKSON
# 15        16          RICHARD CORRIEA
# 25        26             GREGORY SUHR
# ...      ...                      ...
# 35131  35132  CYNTHIA HAYNES-EPPERSON
# 35151  35152               LYNN BLOOM
# 35318  35319           ROBERT CHAPMAN
# 35671  35672            RUSSELL MATLI
# 35902  35903               SUSAN ROTH
#
#                                       JobTitle    BasePay  OvertimePay  \
# 1              CAPTAIN III (POLICE DEPARTMENT)  155966.02    245131.88
# 2              CAPTAIN III (POLICE DEPARTMENT)  212739.13    106088.18
# 11             CAPTAIN III (POLICE DEPARTMENT)   99722.00     87082.62
# 15          COMMANDER III, (POLICE DEPARTMENT)  198778.01     73478.20
# 25                             CHIEF OF POLICE  256470.41         0.00
# ...                                        ...        ...          ...
# ...

# %%
#mesleginin adinda Police olanlar
Police=SF.loc[SF['JobTitle'].str.contains('Police')]
len(Police)
# Out:
# 5665

# %%
#mesleginin adinda police olanlar
police=SF.loc[SF['JobTitle'].str.contains('police')]
len(police)
# Out:
# 0

# %%
#mesleginin adinda hem POLICE hem Police olanlar
polis=SF.loc[SF['JobTitle'].str.contains('POLICE|Police')]
len(polis)
# Out:
# 8177

# %%
#Isminde LISA olanlar
LISA=SF.loc[SF['EmployeeName'].str.contains('LISA')]
len(LISA)
# Out:
# 173

# %%
#Isminde Lisa olanlar

Lisa=SF.loc[SF['EmployeeName'].str.contains('Lisa')]
len(Lisa)
# Out:
# 446

# %%
#Isminde lisa olanlar

lisa=SF.loc[SF['EmployeeName'].str.contains('lisa')]
len(lisa)
# Out:
# 113

# %%
#Isminde lisa Lisa LISA  olanlar
#Lisalar
lisalar=SF.loc[SF['EmployeeName'].str.contains('Lisa|LISA|lisa')]
len(lisalar)
# Out:
# 732

# %%
lisalar
# Out:
#             Id         EmployeeName                               JobTitle  \
# 337        338          LISA GOLDEN       SUPERVISING PHYSICIAN SPECIALIST
# 407        408        LISA HOFFMANN                     DEPUTY DIRECTOR IV
# 564        565        ELISA RAMIREZ                          NURSE MANAGER
# 734        735     ELISABETH FILISS  CAPTAIN, EMERGENCYCY MEDICAL SERVICES
# 845        846          LISA FRAZER       SERGEANT III (POLICE DEPARTMENT)
# ...        ...                  ...                                    ...
# 148090  148091      Lisa A Woodward                Media/Security Sys Spec
# 148137  148138  Anna Lisa M Austria                          Special Nurse
# 148138  148139  Elisabeth M Kaufman                          Special Nurse
# 148248  148249        Lisa K Mihaly                     Nurse Practitioner
# 148542  148543    Lisamarie E Russo                      Recreation Leader
#
# ...

# %%
#Isminde lisa Lisa LISA  olanlar
#mesleginin adinda hem POLICE hem Police olanlar
#Polis_Lisa
Polis_Lisa= SF.loc[SF['JobTitle'].str.contains('POLICE|Police') & SF['EmployeeName'].str.contains('Lisa|LISA|lisa')]
len(Polis_Lisa)
# Out:
# 14

# %%
Polis_Lisa
# Out:
#             Id    EmployeeName                                 JobTitle  \
# 845        846     LISA FRAZER         SERGEANT III (POLICE DEPARTMENT)
# 4037      4038   LISA SPRINGER         SERGEANT III (POLICE DEPARTMENT)
# 4404      4405      LISA SMITH                         POLICE OFFICER I
# 8475      8476  LISA ELEKWACHI  SENIOR POLICE COMMUNICATIONS DISPATCHER
# 8563      8564      LISA CURRY                       POLICE OFFICER III
# 9814      9815     LISA GARCIA                       POLICE OFFICER III
# 39344    39345      Lisa Smith                         Police Officer 2
# 43022    43023     Lisa Garcia                         Police Officer 3
# 49914    49915      Lisa Curry                         Police Officer 3
# 78812    78813    Lisa M Smith                         Police Officer 2
# 79527    79528   Lisa C Garcia                         Police Officer 3
# 117684  117685    Lisa M Smith                         Police Officer 2
# ...

# %%
#Lisa_Springer
#Isminde lisa Lisa LISA  olanlar
#mesleginin adinda hem POLICE hem Police olanlar
#BasePay>130481
#TotalPayBenefits<131493
Lisa_Springer=SF.loc[((SF['JobTitle'].str.contains('POLICE|Police')) & (SF['EmployeeName'].str.contains('Lisa|LISA|lisa'))) & ((SF['BasePay']>130481) & (SF['TotalPayBenefits']<131493))]
len(Lisa_Springer)
# Out:
# 1

# %%
Lisa_Springer
# Out:
#         Id   EmployeeName                          JobTitle   BasePay  \
# 4037  4038  LISA SPRINGER  SERGEANT III (POLICE DEPARTMENT)  130481.3
#
#       OvertimePay  OtherPay   TotalPay  TotalPayBenefits  Year
# 4037          0.0   1011.61  131492.91         131492.91  2011

# %%
##diger yol
Lisa_Springer2=SF.loc[(SF['JobTitle'].str.contains('POLICE|Police')) & (SF['EmployeeName'].str.contains('Lisa|LISA|lisa')) & (SF['BasePay']>130481) & (SF['TotalPayBenefits']<131493)]
len(Lisa_Springer2)
# Out:
# 1

# %%
Lisa_Springer2
# Out:
#         Id   EmployeeName                          JobTitle   BasePay  \
# 4037  4038  LISA SPRINGER  SERGEANT III (POLICE DEPARTMENT)  130481.3
#
#       OvertimePay  OtherPay   TotalPay  TotalPayBenefits  Year
# 4037          0.0   1011.61  131492.91         131492.91  2011
